# %% [markdown]
# # Siddharth Trade Pipeline - Auto-generated notebook
#
# This notebook runs the ETL pipeline:
# 1. Clean raw Excel -> data/processed/clean_base.csv
# 2. Parse goods description -> data/processed/trade_parsed.csv
# 3. Feature engineering -> data/processed/trade_cleaned.csv
# 4. (Optional) Load to local SQLite DB
#
# **Before you run:** place your Excel file at `data/raw/sample_data.xlsx`.

# %% [markdown]
# ## 1) Install required packages
# Run this cell only if packages are missing.

# %%
# !pip install pandas numpy sqlalchemy openpyxl psycopg2-binary python-dotenv regex
print('Skip install if using environment')
# Out:
# Skip install if using environment

# %% [markdown]
# ## 2) Run cleaning

# %%
# !python src/cleaning/clean_base.py
# Out:
# python: can't open file 'c:\\Users\\UMA\\Downloads\\siddharth_trade_pipeline\\siddharth_trade_pipeline\\notebooks\\src\\cleaning\\clean_base.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 3) Run parsing

# %%
# !python src/parsing/parse_goods_description.py
# Out:
# python: can't open file 'c:\\Users\\UMA\\Downloads\\siddharth_trade_pipeline\\siddharth_trade_pipeline\\notebooks\\src\\parsing\\parse_goods_description.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 4) Run feature engineering

# %%
# !python src/feature_engineering/features.py
# Out:
# python: can't open file 'c:\\Users\\UMA\\Downloads\\siddharth_trade_pipeline\\siddharth_trade_pipeline\\notebooks\\src\\feature_engineering\\features.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 5) Optional: load to local SQLite DB

# %%
# !python src/db/load_to_db.py

print('Pipeline finished. Check data/processed for outputs.')
# Out:
# Pipeline finished. Check data/processed for outputs.
# python: can't open file 'c:\\Users\\UMA\\Downloads\\siddharth_trade_pipeline\\siddharth_trade_pipeline\\notebooks\\src\\db\\load_to_db.py': [Errno 2] No such file or directory
